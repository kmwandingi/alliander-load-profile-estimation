# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mpld3

# %%
telemetry_df=pd.read_feather("telemetry_large_consumers_DCW.feather")

# %% [markdown]
# ## Transform the Wide Format to Long Format

# %%
telemetry_df
# Out:
#       RND_ID  2023-01-01 00:00  2023-01-01 00:15  2023-01-01 00:30  \
# 0       8423               0.0               0.0               0.0
# 1       6756              36.0              32.0              32.0
# 2       1077               0.0               4.0               0.0
# 3       8061              16.0               8.0              12.0
# 4      10575               0.0               4.0               0.0
# ...      ...               ...               ...               ...
# 17097  12403               4.0               8.0               4.0
# 17098   3076              16.0              16.0              16.0
# 17099   3076              16.0              16.0              16.0
# 17100   5060               4.0               4.0               8.0
# 17101   6693               0.0               4.0               0.0
#
#        2023-01-01 00:45  2023-01-01 01:00  2023-01-01 01:15  2023-01-01 01:30  \
# 0                   0.0               4.0               0.0               0.0
# 1                  36.0              32.0              36.0              32.0
# 2                   4.0               0.0               4.0               0.0
# 3                   8.0              12.0              16.0              12.0
# 4                   0.0               4.0               0.0               0.0
# ...                 ...               ...               ...               ...
# 17097               4.0               4.0               4.0               4.0
# 17098              16.0              12.0              16.0              12.0
# 17099              16.0              12.0              16.0              12.0
# 17100               4.0               4.0               4.0               4.0
# 17101               4.0               0.0               4.0               0.0
#
#        2023-01-01 01:45  2023-01-01 02:00  ...  2023-12-31 21:30  \
# 0                   0.0               4.0  ...              0.00
# 1                  36.0              32.0  ...             35.89
# 2                   4.0               0.0  ...              2.00
# 3                  12.0              12.0  ...              8.40
# 4                   4.0               0.0  ...              6.67
# ...                 ...               ...  ...               ...
# 17097               4.0               4.0  ...              6.50
# 17098              16.0              12.0  ...              0.73
# 17099              16.0              12.0  ...              0.73
# 17100               8.0               4.0  ...              5.86
# 17101               4.0               4.0  ...              2.05
#
#        2023-12-31 21:45  2023-12-31 22:00  2023-12-31 22:15  2023-12-31 22:30  \
# 0                  0.00              0.00              0.00              0.00
# 1                 35.43             34.09             33.31             30.57
# 2                  1.50              1.50              2.00              1.50
# 3                  8.80              8.80             11.00             10.19
# 4                  6.66              3.54              1.15              1.10
# ...                 ...               ...               ...               ...
# 17097              5.00              5.50              5.50              5.50
# 17098              0.44              0.44              0.46              0.44
# 17099              0.44              0.44              0.46              0.44
# 17100              5.87              5.98              5.91              5.71
# 17101              2.00              1.95              2.20              1.95
#
#        2023-12-31 22:45  2023-12-31 23:00  2023-12-31 23:15  2023-12-31 23:30  \
# 0                  0.00              0.00              0.00              0.00
# 1                 29.65             32.06             29.13             28.25
# 2                  1.50              2.00              1.50              2.00
# 3                  9.19              8.80              9.00             11.00
# 4                  1.10              1.10              1.10              1.10
# ...                 ...               ...               ...               ...
# 17097              4.50              4.00              4.00              3.50
# 17098              0.44              0.46              0.44              0.46
# 17099              0.44              0.46              0.44              0.46
# 17100              6.41              5.70              7.20              5.62
# 17101              1.95              2.05              2.00              2.00
#
#        2023-12-31 23:45
# 0                  0.00
# 1                 27.85
# 2                  1.50
# 3                 12.40
# 4                  1.12
# ...                 ...
# 17097              4.00
# 17098              0.46
# 17099              0.46
# 17100              5.94
# 17101              2.00
#
# [17102 rows x 35041 columns]

# %%
# Check for missing values
missing_data = telemetry_df.isnull().sum()
missing_data
# Out:
# RND_ID               0
# 2023-01-01 00:00     3
# 2023-01-01 00:15     3
# 2023-01-01 00:30     3
# 2023-01-01 00:45     3
#                     ..
# 2023-12-31 22:45    13
# 2023-12-31 23:00    34
# 2023-12-31 23:15    34
# 2023-12-31 23:30    34
# 2023-12-31 23:45    34
# Length: 35041, dtype: int64

# %%
df_long = pd.melt(telemetry_df, id_vars=['RND_ID'], var_name='datetime', value_name='load')

# %%
df_long.head(30)
# Out:
#                             load  load_lag_1  load_lag_2  load_lag_3  \
# RND_ID datetime
# 4080   2023-01-01 00:30:00  24.0        20.0        20.0        16.0
#        2023-01-01 00:30:00  24.0        24.0        20.0        20.0
# 5864   2023-01-01 00:30:00   0.0         0.0         0.0         0.0
#        2023-01-01 00:30:00   0.0         0.0         0.0         0.0
# 1163   2023-01-01 00:30:00  12.0        16.0        16.0        12.0
#        2023-01-01 00:30:00  12.0        12.0        16.0        16.0
# 2271   2023-01-01 00:30:00   0.0         0.0         0.0         0.0
#        2023-01-01 00:30:00   0.0         0.0         0.0         0.0
# 7302   2023-01-01 00:30:00  16.0        16.0        16.0        16.0
#        2023-01-01 00:30:00  16.0        16.0        16.0        16.0
# 457    2023-01-01 00:30:00   4.0         8.0         8.0         4.0
#        2023-01-01 00:30:00   4.0         4.0         8.0         8.0
# 10524  2023-01-01 00:30:00  44.0        40.0        40.0        40.0
#        2023-01-01 00:30:00  44.0        44.0        40.0        40.0
# 874    2023-01-01 00:30:00  20.0        16.0        16.0        16.0
#        2023-01-01 00:30:00  20.0        20.0        16.0        16.0
# 5407   2023-01-01 00:30:00   0.0         0.0         0.0         0.0
#        2023-01-01 00:30:00   0.0         0.0         0.0         0.0
# 10344  2023-01-01 00:30:00  16.0        16.0        16.0        16.0
#        2023-01-01 00:30:00  16.0        16.0        16.0        16.0
# 8040   2023-01-01 00:30:00   4.0        12.0        12.0         8.0
#        2023-01-01 00:30:00   4.0         4.0        12.0        12.0
# 5153   2023-01-01 00:30:00   4.0         0.0         0.0         0.0
#        2023-01-01 00:30:00   4.0         4.0         0.0         0.0
# 11025  2023-01-01 00:30:00  12.0         8.0         8.0        12.0
#        2023-01-01 00:30:00  12.0        12.0         8.0         8.0
# 2023   2023-01-01 00:30:00   4.0         4.0         4.0         4.0
#        2023-01-01 00:30:00   4.0         4.0         4.0         4.0
# 7284   2023-01-01 00:30:00   4.0         4.0         4.0         4.0
#        2023-01-01 00:30:00   4.0         4.0         4.0         4.0
#
#                             load_lag_4
# RND_ID datetime
# 4080   2023-01-01 00:30:00        16.0
#        2023-01-01 00:30:00        16.0
# 5864   2023-01-01 00:30:00         0.0
#        2023-01-01 00:30:00         0.0
# 1163   2023-01-01 00:30:00        12.0
#        2023-01-01 00:30:00        12.0
# 2271   2023-01-01 00:30:00         0.0
#        2023-01-01 00:30:00         0.0
# 7302   2023-01-01 00:30:00        16.0
#        2023-01-01 00:30:00        16.0
# 457    2023-01-01 00:30:00         4.0
#        2023-01-01 00:30:00         4.0
# 10524  2023-01-01 00:30:00        40.0
#        2023-01-01 00:30:00        40.0
# 874    2023-01-01 00:30:00        16.0
#        2023-01-01 00:30:00        16.0
# 5407   2023-01-01 00:30:00         0.0
#        2023-01-01 00:30:00         0.0
# 10344  2023-01-01 00:30:00        16.0
#        2023-01-01 00:30:00        16.0
# 8040   2023-01-01 00:30:00         8.0
#        2023-01-01 00:30:00         8.0
# 5153   2023-01-01 00:30:00         0.0
#        2023-01-01 00:30:00         0.0
# 11025  2023-01-01 00:30:00        12.0
#        2023-01-01 00:30:00        12.0
# 2023   2023-01-01 00:30:00         4.0
#        2023-01-01 00:30:00         4.0
# 7284   2023-01-01 00:30:00         4.0
#        2023-01-01 00:30:00         4.0

# %%
# Convert the datetime column to datetime format
df_long['datetime'] = pd.to_datetime(df_long['datetime'])

# %%
# Set the index for easier time series manipulation
df_long.set_index(['RND_ID', 'datetime'], inplace=True)

# %%
df_long.info()

# %% [markdown]
# # Create lags for 15min, 30min, 45min, and 1 hour

# %%
# Create lagged features
for lag in [1, 2,3,4]:  # Create lags for 15min, 30min, 45min, and 1 hour
    df_long[f'load_lag_{lag}'] = df_long.groupby('RND_ID')['load'].shift(lag)

# Drop NaN values that result from lagging
df_long = df_long.dropna()

# Reset index to have a clean DataFrame
df_long = df_long.reset_index()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Create lagged features
#       2 for lag in [1, 2,3,4]:  # Create lags for 15min, 30min, 45min, and 1 hour
# ----> 3     df_long[f'load_lag_{lag}'] = df_long.groupby('RND_ID')['load'].shift(lag)
#       5 # Drop NaN values that result from lagging
#       6 df_long = df_long.dropna()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:996, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     991         in_axis = False
#     993     # create the Grouping
#     994     # allow us to passing the actual Grouping as the gpr
#     995     ping = (
# --> 996         Grouping(
#     997             group_axis,
#     998             gpr,
#     999             obj=obj,
#    1000             level=level,
#    1001             sort=sort,
#    1002             observed=observed,
#    1003             in_axis=in_axis,
#    1004             dropna=dropna,
#    1005         )
#    1006         if not isinstance(gpr, Grouping)
#    1007         else gpr
#    1008     )
#    1010     groupings.append(ping)
#    1012 if len(groupings) == 0 and len(obj):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:542, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna, uniques)
#     537 if ilevel is not None:
#     538     # In extant tests, the new self.grouping_vector matches
#     539     #  `index.get_level_values(ilevel)` whenever
#     540     #  mapper is None and isinstance(index, MultiIndex)
#     541     if isinstance(index, MultiIndex):
# --> 542         index_level = index.get_level_values(ilevel)
#     543     else:
#     544         index_level = index
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:1656, in MultiIndex.get_level_values(self, level)
#    1608 """
#    1609 Return vector of label values for requested level.
#    1610
#    (...)
#    1653 Index([1.0, nan, 2.0], dtype='float64')
#    1654 """
#    1655 level = self._get_level_number(level)
# -> 1656 values = self._get_level_values(level)
#    1657 return values
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:1604, in MultiIndex._get_level_values(self, level, unique)
#    1602 if unique:
#    1603     level_codes = algos.unique(level_codes)
# -> 1604 filled = algos.take_nd(lev._values, level_codes, fill_value=lev._na_value)
#    1605 return lev._shallow_copy(filled, name=name)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:131, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     129     dtype, fill_value = arr.dtype, arr.dtype.type()
#     130 else:
# --> 131     indexer = ensure_platform_int(indexer)
#     133 dtype, fill_value, mask_info = _take_preprocess_indexer_and_fill_value(
#     134     arr, indexer, fill_value, allow_fill
#     135 )
#     137 flip_order = False
#
# File pandas\_libs\algos_common_helper.pxi:20, in pandas._libs.algos.ensure_platform_int()
#
# MemoryError: Unable to allocate 4.46 GiB for an array with shape (599012952,) and data type int64

# %% [markdown]
# # Create historical statistics features (mean, median, std)

# %%
# Create historical statistics features (mean, median, std)
window_size = 4  # Example window size for rolling statistics (1 hour)
df_long['load_mean'] = df_long.groupby('RND_ID')['load'].transform(lambda x: x.rolling(window=window_size).mean())
df_long['load_median'] = df_long.groupby('RND_ID')['load'].transform(lambda x: x.rolling(window=window_size).median())
df_long['load_std'] = df_long.groupby('RND_ID')['load'].transform(lambda x: x.rolling(window=window_size).std())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[45], line 3
#       1 # Create historical statistics features (mean, median, std)
#       2 window_size = 4  # Example window size for rolling statistics (1 hour)
# ----> 3 df_long['load_mean'] = df_long.groupby('RND_ID')['load'].transform(lambda x: x.rolling(window=window_size).mean())
#       4 df_long['load_median'] = df_long.groupby('RND_ID')['load'].transform(lambda x: x.rolling(window=window_size).median())
#       5 df_long['load_std'] = df_long.groupby('RND_ID')['load'].transform(lambda x: x.rolling(window=window_size).std())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:996, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     991         in_axis = False
#     993     # create the Grouping
#     994     # allow us to passing the actual Grouping as the gpr
#     995     ping = (
# --> 996         Grouping(
#     997             group_axis,
#     998             gpr,
#     999             obj=obj,
#    1000             level=level,
#    1001             sort=sort,
#    1002             observed=observed,
#    1003             in_axis=in_axis,
#    1004             dropna=dropna,
#    1005         )
#    1006         if not isinstance(gpr, Grouping)
#    1007         else gpr
#    1008     )
#    1010     groupings.append(ping)
#    1012 if len(groupings) == 0 and len(obj):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:542, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna, uniques)
#     537 if ilevel is not None:
#     538     # In extant tests, the new self.grouping_vector matches
#     539     #  `index.get_level_values(ilevel)` whenever
#     540     #  mapper is None and isinstance(index, MultiIndex)
#     541     if isinstance(index, MultiIndex):
# --> 542         index_level = index.get_level_values(ilevel)
#     543     else:
#     544         index_level = index
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:1656, in MultiIndex.get_level_values(self, level)
#    1608 """
#    1609 Return vector of label values for requested level.
#    1610
#    (...)
#    1653 Index([1.0, nan, 2.0], dtype='float64')
#    1654 """
#    1655 level = self._get_level_number(level)
# -> 1656 values = self._get_level_values(level)
#    1657 return values
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:1604, in MultiIndex._get_level_values(self, level, unique)
#    1602 if unique:
#    1603     level_codes = algos.unique(level_codes)
# -> 1604 filled = algos.take_nd(lev._values, level_codes, fill_value=lev._na_value)
#    1605 return lev._shallow_copy(filled, name=name)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:131, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     129     dtype, fill_value = arr.dtype, arr.dtype.type()
#     130 else:
# --> 131     indexer = ensure_platform_int(indexer)
#     133 dtype, fill_value, mask_info = _take_preprocess_indexer_and_fill_value(
#     134     arr, indexer, fill_value, allow_fill
#     135 )
#     137 flip_order = False
#
# File pandas\_libs\algos_common_helper.pxi:20, in pandas._libs.algos.ensure_platform_int()
#
# MemoryError: Unable to allocate 4.46 GiB for an array with shape (599012952,) and data type int64

# %%
# Create Fourier series terms for capturing periodic patterns
def create_fourier_terms(df, period):
    t = np.arange(len(df))
    df[f'sin_{period}'] = np.sin(2 * np.pi * t / period)
    df[f'cos_{period}'] = np.cos(2 * np.pi * t / period)
    return df

periods = [96, 672]  # Example periods for daily (96 intervals) and weekly (672 intervals) patterns
for period in periods:
    df_long = df_long.groupby('RND_ID').apply(create_fourier_terms, period=period).reset_index(drop=True)

# Drop NaN values that result from lagging and rolling calculations
df_long = df_long.dropna()

# Reset index to have a clean DataFrame
df_long = df_long.reset_index()

# The resulting DataFrame df_long now contains the lagged features, historical statistics, and Fourier series terms
print(df_long.head())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[44], line 10
#       8 periods = [96, 672]  # Example periods for daily (96 intervals) and weekly (672 intervals) patterns
#       9 for period in periods:
# ---> 10     df_long = df_long.groupby('RND_ID').apply(create_fourier_terms, period=period).reset_index(drop=True)
#      12 # Drop NaN values that result from lagging and rolling calculations
#      13 df_long = df_long.dropna()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:996, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     991         in_axis = False
#     993     # create the Grouping
#     994     # allow us to passing the actual Grouping as the gpr
#     995     ping = (
# --> 996         Grouping(
#     997             group_axis,
#     998             gpr,
#     999             obj=obj,
#    1000             level=level,
#    1001             sort=sort,
#    1002             observed=observed,
#    1003             in_axis=in_axis,
#    1004             dropna=dropna,
#    1005         )
#    1006         if not isinstance(gpr, Grouping)
#    1007         else gpr
#    1008     )
#    1010     groupings.append(ping)
#    1012 if len(groupings) == 0 and len(obj):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:542, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna, uniques)
#     537 if ilevel is not None:
#     538     # In extant tests, the new self.grouping_vector matches
#     539     #  `index.get_level_values(ilevel)` whenever
#     540     #  mapper is None and isinstance(index, MultiIndex)
#     541     if isinstance(index, MultiIndex):
# --> 542         index_level = index.get_level_values(ilevel)
#     543     else:
#     544         index_level = index
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:1656, in MultiIndex.get_level_values(self, level)
#    1608 """
#    1609 Return vector of label values for requested level.
#    1610
#    (...)
#    1653 Index([1.0, nan, 2.0], dtype='float64')
#    1654 """
#    1655 level = self._get_level_number(level)
# -> 1656 values = self._get_level_values(level)
#    1657 return values
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:1604, in MultiIndex._get_level_values(self, level, unique)
#    1602 if unique:
#    1603     level_codes = algos.unique(level_codes)
# -> 1604 filled = algos.take_nd(lev._values, level_codes, fill_value=lev._na_value)
#    1605 return lev._shallow_copy(filled, name=name)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:131, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     129     dtype, fill_value = arr.dtype, arr.dtype.type()
#     130 else:
# --> 131     indexer = ensure_platform_int(indexer)
#     133 dtype, fill_value, mask_info = _take_preprocess_indexer_and_fill_value(
#     134     arr, indexer, fill_value, allow_fill
#     135 )
#     137 flip_order = False
#
# File pandas\_libs\algos_common_helper.pxi:20, in pandas._libs.algos.ensure_platform_int()
#
# MemoryError: Unable to allocate 4.46 GiB for an array with shape (599012952,) and data type int64
